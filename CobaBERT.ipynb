# %%
from transformers import BertForSequenceClassification, BertConfig, BertTokenizer
import tensorflow_hub as hub

# %%
# Load Tokenizer and Config
tokenizer = BertTokenizer.from_pretrained('indobenchmark/indobert-base-p1')
config = BertConfig.from_pretrained('indobenchmark/indobert-base-p1')
config.num_labels = 3

# Instantiate model
model = BertForSequenceClassification.from_pretrained('indobenchmark/indobert-base-p1', config=config)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at indobenchmark/indobert-base-p1 and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model

# %%
elmo = hub.load('https://tfhub.dev/google/elmo/2')

# %%
elmo

# %%
import torch
torch.manual_seed(0)
from transformers import BertTokenizer, BertModel

import logging
import matplotlib.pyplot as plt

# %%
# Load pre-trained model tokenizer (vocabulary)
tokenizer = BertTokenizer.from_pretrained('indobenchmark/indobert-base-p1', do_lower_case=True)

# %%
import pandas as pd
df_full = pd.read_csv('entailment_dataset_1.csv')
df = df_full.iloc[[0,1,2,18,19,20,60, 61, 62, 63,64,65],:]

# %%
for row in df['Kalimat Premis']:
    print(row)
# Out:
# Tiga kali Devano menikah, dan ketiga istrinya itu pun meninggal dengan mengenaskan
# Tiga kali Devano menikah, dan ketiga istrinya itu pun meninggal dengan mengenaskan
# Tiga kali Devano menikah, dan ketiga istrinya itu pun meninggal dengan mengenaskan
# 1942, adalah kali terakhir kami melihat orang orang itu menginjakan kaki di tanah ini.
# 1942, adalah kali terakhir kami melihat orang orang itu menginjakan kaki di tanah ini.
# 1942, adalah kali terakhir kami melihat orang orang itu menginjakan kaki di tanah ini.
# Pada  masa  pendudukan  Jepang,  Gua  Jepang  digunakan  sebagai  benteng perlindungan tentara Jepang dari serangan musuh
# Pada  masa  pendudukan  Jepang,  Gua  Jepang  digunakan  sebagai  benteng perlindungan tentara Jepang dari serangan musuh
# Pada  masa  pendudukan  Jepang,  Gua  Jepang  digunakan  sebagai  benteng perlindungan tentara Jepang dari serangan musuh
# Kedatangan  Jepang  di  Indonesia  pada  awalnya  disambut  dengan  senang hati  oleh  rakyat  Indonesia.
# Kedatangan  Jepang  di  Indonesia  pada  awalnya  disambut  dengan  senang hati  oleh  rakyat  Indonesia.
# Kedatangan  Jepang  di  Indonesia  pada  awalnya  disambut  dengan  senang hati  oleh  rakyat  Indonesia.

# %%
sentences = [row for row in df['Kalimat Premis']]
sentlabels = [row for row in df['Kalimat Hypothesis']]
sentences += sentlabels
sentences.append("Kedatangan  Jepang  di  Indonesia  pada  awalnya  disambut  dengan  senang hati  oleh  rakyat  di negara ini")
# Print the original sentence.
print(' Teks Asli: ', sentences[12][:99])
# Print the sentence splitted into tokens.
print('Tokenisasi: ', tokenizer.tokenize(sentences[0])[:15])
# Print the sentence mapped to token ids.
print('     Hasil: ', tokenizer.convert_tokens_to_ids(tokenizer.tokenize(sentences[0]))[:15])
# Out:
#  Teks Asli:  Devano adalah seorang pembunuh
# Tokenisasi:  ['tiga', 'kali', 'dev', '##ano', 'menikah', ',', 'dan', 'ketiga', 'istrinya', 'itu', 'pun', 'meninggal', 'dengan', 'mengen', '##askan']
#      Hasil:  [1224, 633, 5780, 13126, 3335, 30468, 41, 2243, 6341, 137, 573, 1851, 79, 753, 1656]

# %%
# Tokenize all of the sentences and map tokens to word IDs.
input_ids = []
attention_masks = []
tokenized_texts = []
for sent in sentences:
    encoded_dict = tokenizer.encode_plus(
                        sent,                      
                        add_special_tokens = True,
                        truncation=True,
                        max_length = 48,          
                        pad_to_max_length = True,                        
                        return_tensors = 'pt',    
                   )
    # Save tokens from sentence as a separate array. 
    marked_text = "[CLS] " + sent + " [SEP]"
    tokenized_texts.append(tokenizer.tokenize(marked_text))
    
    # Add the encoded sentence to the list.    
    input_ids.append(encoded_dict['input_ids'])
# Convert the list into tensor.
input_ids = torch.cat(input_ids, dim=0)
# Out:
# D:\Anaconda\envs\textEntail\lib\site-packages\transformers\tokenization_utils_base.py:2149: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
tokenized_texts
# Out:
# [['[CLS]',
#   'tiga',
#   'kali',
#   'dev',
#   '##ano',
#   'menikah',
#   ',',
#   'dan',
#   'ketiga',
#   'istrinya',
#   'itu',
#   'pun',
#   'meninggal',
#   'dengan',
#   'mengen',
#   '##askan',
#   '[SEP]'],
#  ['[CLS]',
#   'tiga',
#   'kali',
#   'dev',
#   '##ano',
#   'menikah',
#   ',',
#   'dan',
#   'ketiga',
#   'istrinya',
#   'itu',
#   'pun',
#   'meninggal',
#   'dengan',
#   'mengen',
#   '##askan',
#   '[SEP]'],
#  ['[CLS]',
#   'tiga',
#   'kali',
#   'dev',
#   '##ano',
#   'menikah',
#   ',',
#   'dan',
#   'ketiga',
#   'istrinya',
#   'itu',
#   'pun',
#   'meninggal',
#   'dengan',
#   'mengen',
#   '##askan',
#   '[SEP]'],
#  ['[CLS]',
#   '1942',
#   ',',
#   'adalah',
#   'kali',
#   'terakhir',
#   'kami',
#   'melihat',
#   'orang',
#   'orang',
#   'itu',
#   'menginjak',
#   '##an',
#   'kaki',
#   'di',
#   'tanah',
#   'ini',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '1942',
#   ',',
#   'adalah',
#   'kali',
#   'terakhir',
#   'kami',
#   'melihat',
#   'orang',
#   'orang',
#   'itu',
#   'menginjak',
#   '##an',
#   'kaki',
#   'di',
#   'tanah',
#   'ini',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '1942',
#   ',',
#   'adalah',
#   'kali',
#   'terakhir',
#   'kami',
#   'melihat',
#   'orang',
#   'orang',
#   'itu',
#   'menginjak',
#   '##an',
#   'kaki',
#   'di',
#   'tanah',
#   'ini',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'pada',
#   'masa',
#   'pendudukan',
#   'jepang',
#   ',',
#   'gua',
#   'jepang',
#   'digunakan',
#   'sebagai',
#   'benteng',
#   'perlindungan',
#   'tentara',
#   'jepang',
#   'dari',
#   'serangan',
#   'musuh',
#   '[SEP]'],
#  ['[CLS]',
#   'pada',
#   'masa',
#   'pendudukan',
#   'jepang',
#   ',',
#   'gua',
#   'jepang',
#   'digunakan',
#   'sebagai',
#   'benteng',
#   'perlindungan',
#   'tentara',
#   'jepang',
#   'dari',
#   'serangan',
#   'musuh',
#   '[SEP]'],
#  ['[CLS]',
#   'pada',
#   'masa',
#   'pendudukan',
#   'jepang',
#   ',',
#   'gua',
#   'jepang',
#   'digunakan',
#   'sebagai',
#   'benteng',
#   'perlindungan',
#   'tentara',
#   'jepang',
#   'dari',
#   'serangan',
#   'musuh',
#   '[SEP]'],
#  ['[CLS]',
#   'kedatangan',
#   'jepang',
#   'di',
#   'indonesia',
#   'pada',
#   'awalnya',
#   'disambut',
#   'dengan',
#   'senang',
#   'hati',
#   'oleh',
#   'rakyat',
#   'indonesia',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'kedatangan',
#   'jepang',
#   'di',
#   'indonesia',
#   'pada',
#   'awalnya',
#   'disambut',
#   'dengan',
#   'senang',
#   'hati',
#   'oleh',
#   'rakyat',
#   'indonesia',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'kedatangan',
#   'jepang',
#   'di',
#   'indonesia',
#   'pada',
#   'awalnya',
#   'disambut',
#   'dengan',
#   'senang',
#   'hati',
#   'oleh',
#   'rakyat',
#   'indonesia',
#   '.',
#   '[SEP]'],
#  ['[CLS]', 'dev', '##ano', 'adalah', 'seorang', 'pembunuh', '[SEP]'],
#  ['[CLS]', 'dev', '##ano', 'tidak', 'memiliki', 'istri', '[SEP]'],
#  ['[CLS]', 'ketiga', 'istri', 'dev', '##ano', 'bunuh', 'diri', '[SEP]'],
#  ['[CLS]',
#   'ras',
#   'kulit',
#   'putih',
#   'telah',
#   'meninggalkan',
#   'indonesia',
#   '[SEP]'],
#  ['[CLS]', 'ras', 'kulit', 'putih', 'meninggal', 'dunia', '[SEP]'],
#  ['[CLS]',
#   'tahun',
#   '1942',
#   'adalah',
#   'hari',
#   'em',
#   '##erdekaan',
#   'indonesia',
#   '[SEP]'],
#  ['[CLS]', 'tentara', 'jepang', 'mendapatkan', 'serangan', '[SEP]'],
#  ['[CLS]', 'gua', 'jepang', 'terletak', 'di', 'jepang', '[SEP]'],
#  ['[CLS]',
#   'tentara',
#   'jepang',
#   'telah',
#   'menj',
#   '##ajah',
#   'indonesia',
#   '[SEP]'],
#  ['[CLS]', 'rakyat', 'indonesia', 'menyukai', 'kedatangan', 'jepang', '[SEP]'],
#  ['[CLS]', 'jepang', 'ke', 'indonesia', 'untuk', 'liburan', '[SEP]'],
#  ['[CLS]', 'rakyat', 'indonesia', 'memiliki', 'hati', 'yang', 'baik', '[SEP]'],
#  ['[CLS]',
#   'kedatangan',
#   'jepang',
#   'di',
#   'indonesia',
#   'pada',
#   'awalnya',
#   'disambut',
#   'dengan',
#   'senang',
#   'hati',
#   'oleh',
#   'rakyat',
#   'di',
#   'negara',
#   'ini',
#   '[SEP]']]

# %%
segments_ids = torch.ones_like(input_ids)
segments_ids.shape
# Out:
# torch.Size([25, 48])

# %%
model = BertModel.from_pretrained('indobenchmark/indobert-base-p1',
                                  output_hidden_states = True, # Whether the model returns all hidden-states.
                                  )
model.eval();

# %%
with torch.no_grad():

    outputs = model(input_ids, segments_ids)

    # Evaluating the model will return a different number of objects based on 
    # how it's  configured in the `from_pretrained` call earlier. In this case, 
    # becase we set `output_hidden_states = True`, the third item will be the 
    # hidden states from all layers. See the documentation for more details:
    # https://huggingface.co/transformers/model_doc/bert.html#bertmodel
    hidden_states = outputs[2]

# %%
print ("Number of layers:", len(hidden_states), "  (initial embeddings + 12 BERT layers)")
print ("Number of batches:", len(hidden_states[0]))
print ("Number of tokens:", len(hidden_states[0][0]))
print ("Number of hidden units:", len(hidden_states[0][0][0]))
# Out:
# Number of layers: 13   (initial embeddings + 12 BERT layers)
# Number of batches: 25
# Number of tokens: 48
# Number of hidden units: 768

# %%
# Concatenate the tensors for all layers. We use `stack` here to
# create a new dimension in the tensor.
token_embeddings = torch.stack(hidden_states, dim=0)

token_embeddings.size()
# Out:
# torch.Size([13, 25, 48, 768])

# %%
# Swap dimensions, so we get tensors in format: [sentence, tokens, hidden layes, features]
token_embeddings = token_embeddings.permute(1,2,0,3)

token_embeddings.size()
# Out:
# torch.Size([25, 48, 13, 768])

# %%
# we will use last four hidden layers to create each word embedding

processed_embeddings = token_embeddings[:, :, 9:, :]
processed_embeddings.shape
# Out:
# torch.Size([25, 48, 4, 768])

# %%
# Concatenate four layers for each token to create embeddings

embeddings = torch.reshape(processed_embeddings, (4, 48, -1))
embeddings.shape
# Out:
# torch.Size([4, 48, 19200])

# %%
embeddings_cpy = processed_embeddings.clone().detach()

# %%
embeddings_cpy = embeddings_cpy.numpy()

# %%
embeddings_cpy
# Out:
# array([[[[-4.42338586e-01,  2.27511024e+00, -7.52650388e-03, ...,
#           -2.82732517e-01,  1.43674001e-01, -6.40653431e-01],
#          [-3.40156525e-01,  2.73039508e+00,  4.70301539e-01, ...,
#           -1.63167521e-01,  1.93777934e-01, -6.59845889e-01],
#            6.37667537e-01,  1.24860466e+00, -1.92667618e-01],
#          [-7.15730309e-01, -3.48020434e-01,  1.46125543e+00, ...,
#            6.43853903e-01,  1.04872048e+00, -8.10365006e-03],
#          [-5.53816319e-01, -1.37684852e-01,  1.70971942e+00, ...,
#            7.67603040e-01,  1.34277022e+00,  2.96726316e-01],
#          [-4.44407791e-01, -1.07435688e-01,  1.66338861e+00, ...,
#            7.11371183e-01,  1.51683748e+00,  4.73007888e-01]],
#
#         ...,
#
#         [[ 5.77967949e-02,  9.88109291e-01,  9.89271253e-02, ...,
#           -1.44675851e-01, -1.27872229e-01, -1.06437290e+00],
#          [ 5.66080272e-01,  4.76262808e-01,  4.37246889e-01, ...,
#            2.69179583e-01, -4.74997848e-01, -5.81713796e-01],
#          [ 4.83868331e-01,  2.78635740e-01,  1.52454108e-01, ...,
#            3.41547757e-01,  1.30626068e-01, -3.20461959e-01],
#          [ 7.16821074e-01,  2.94462055e-01,  2.68002570e-01, ...,
#            6.24546289e-01,  2.63724715e-01, -1.20768718e-01]],
#
#         [[ 3.80398005e-01,  1.41382968e+00,  3.15313131e-01, ...,
#           -2.67642766e-01,  2.31601164e-01, -9.79332983e-01],
#          [ 7.86752105e-01,  8.84775817e-01,  6.22474551e-01, ...,
#            1.99029326e-01, -1.49550866e-02, -4.45883989e-01],
#          [ 7.25194633e-01,  6.81802988e-01,  2.27403373e-01, ...,
#            2.29068220e-01,  6.20125651e-01, -2.06761807e-01],
#          [ 7.94092000e-01,  7.19643891e-01,  2.84865499e-01, ...,
#            4.68415558e-01,  6.42244220e-01, -4.10083383e-02]],
#
#         [[ 2.03118160e-01,  1.48914278e+00, -3.99866328e-02, ...,
#           -1.85794488e-01,  1.83619447e-02, -8.64713371e-01],
#          [ 6.13167763e-01,  9.03266013e-01,  4.66778249e-01, ...,
#            2.15257138e-01, -1.98808134e-01, -4.14488107e-01],
#          [ 5.70879161e-01,  6.60758078e-01,  2.03083575e-01, ...,
#            2.90490121e-01,  3.65575314e-01, -1.96061820e-01],
#          [ 6.92563832e-01,  6.86681628e-01,  2.19626635e-01, ...,
#            4.66659725e-01,  4.90331024e-01,  1.70043726e-02]]]],
#       dtype=float32)

# %%
df_embed_full = {'teks':[sent for sent in sentences], 'embedding_result':[embed for embed in embeddings_cpy]}

# %%
sentences
# Out:
# ['Tiga kali Devano menikah, dan ketiga istrinya itu pun meninggal dengan mengenaskan',
#  'Tiga kali Devano menikah, dan ketiga istrinya itu pun meninggal dengan mengenaskan',
#  'Tiga kali Devano menikah, dan ketiga istrinya itu pun meninggal dengan mengenaskan',
#  '1942, adalah kali terakhir kami melihat orang orang itu menginjakan kaki di tanah ini. ',
#  '1942, adalah kali terakhir kami melihat orang orang itu menginjakan kaki di tanah ini. ',
#  '1942, adalah kali terakhir kami melihat orang orang itu menginjakan kaki di tanah ini. ',
#  'Pada  masa  pendudukan  Jepang,  Gua  Jepang  digunakan  sebagai  benteng perlindungan tentara Jepang dari serangan musuh',
#  'Pada  masa  pendudukan  Jepang,  Gua  Jepang  digunakan  sebagai  benteng perlindungan tentara Jepang dari serangan musuh',
#  'Pada  masa  pendudukan  Jepang,  Gua  Jepang  digunakan  sebagai  benteng perlindungan tentara Jepang dari serangan musuh',
#  'Kedatangan  Jepang  di  Indonesia  pada  awalnya  disambut  dengan  senang hati  oleh  rakyat  Indonesia. ',
#  'Kedatangan  Jepang  di  Indonesia  pada  awalnya  disambut  dengan  senang hati  oleh  rakyat  Indonesia. ',
#  'Kedatangan  Jepang  di  Indonesia  pada  awalnya  disambut  dengan  senang hati  oleh  rakyat  Indonesia. ',
#  'Devano adalah seorang pembunuh',
#  'Devano tidak memiliki istri',
#  'Ketiga istri devano bunuh diri',
#  'Ras kulit putih telah meninggalkan Indonesia',
#  'Ras kulit putih meninggal dunia',
#  'Tahun 1942 adalah hari emerdekaan Indonesia',
#  'Tentara jepang mendapatkan serangan',
#  'Gua Jepang terletak di Jepang',
#  'Tentara jepang telah menjajah Indonesia',
#  'Rakyat Indonesia menyukai kedatangan Jepang',
#  'Jepang ke Indonesia untuk liburan',
#  'Rakyat Indonesia memiliki hati yang baik',
#  'Kedatangan  Jepang  di  Indonesia  pada  awalnya  disambut  dengan  senang hati  oleh  rakyat  di negara ini']

# %%
print(len(sentences))
print(len(tokenized_texts))
print(len(embeddings_cpy))
print(len([tok for tok in [tokenizer.tokenize(sent)[:15] for sent in sentences]]))
print(len([emb for emb in [tokenizer.convert_tokens_to_ids(tokenizer.tokenize(sent))[:15] for sent in sentences]]))
# Out:
# 25
# 25
# 25
# 25
# 25

# %%
df_embed = {'teks':[sent for sent in sentences], 'tokenization_result':[tok for tok in [tokenizer.tokenize(sent)[:15] for sent in sentences]], 'vector_repr':[emb for emb in [tokenizer.convert_tokens_to_ids(tokenizer.tokenize(sent))[:15] for sent in sentences]],'embedding_result':[embed for embed in embeddings_cpy]}

# %%
df_embed = pd.DataFrame(df_embed)

# %%
df_embed
# Out:
#                                                  teks  \
# 0   Tiga kali Devano menikah, dan ketiga istrinya ...
# 1   Tiga kali Devano menikah, dan ketiga istrinya ...
# 2   Tiga kali Devano menikah, dan ketiga istrinya ...
# 3   1942, adalah kali terakhir kami melihat orang ...
# 4   1942, adalah kali terakhir kami melihat orang ...
# 5   1942, adalah kali terakhir kami melihat orang ...
# 6   Pada  masa  pendudukan  Jepang,  Gua  Jepang  ...
# 7   Pada  masa  pendudukan  Jepang,  Gua  Jepang  ...
# 8   Pada  masa  pendudukan  Jepang,  Gua  Jepang  ...
# 9   Kedatangan  Jepang  di  Indonesia  pada  awaln...
# 10  Kedatangan  Jepang  di  Indonesia  pada  awaln...
# 11  Kedatangan  Jepang  di  Indonesia  pada  awaln...
# 12                     Devano adalah seorang pembunuh
# 13                        Devano tidak memiliki istri
# 14                     Ketiga istri devano bunuh diri
# 15       Ras kulit putih telah meninggalkan Indonesia
# 16                    Ras kulit putih meninggal dunia
# 17        Tahun 1942 adalah hari emerdekaan Indonesia
# 18                Tentara jepang mendapatkan serangan
# 19                      Gua Jepang terletak di Jepang
# 20            Tentara jepang telah menjajah Indonesia
# 21        Rakyat Indonesia menyukai kedatangan Jepang
# 22                  Jepang ke Indonesia untuk liburan
# 23           Rakyat Indonesia memiliki hati yang baik
# 24  Kedatangan  Jepang  di  Indonesia  pada  awaln...
#
#                                   tokenization_result  \
# 0   [tiga, kali, dev, ##ano, menikah, ,, dan, keti...
# 1   [tiga, kali, dev, ##ano, menikah, ,, dan, keti...
# 2   [tiga, kali, dev, ##ano, menikah, ,, dan, keti...
# 3   [1942, ,, adalah, kali, terakhir, kami, meliha...
# 4   [1942, ,, adalah, kali, terakhir, kami, meliha...
# 5   [1942, ,, adalah, kali, terakhir, kami, meliha...
# 6   [pada, masa, pendudukan, jepang, ,, gua, jepan...
# 7   [pada, masa, pendudukan, jepang, ,, gua, jepan...
# 8   [pada, masa, pendudukan, jepang, ,, gua, jepan...
# 9   [kedatangan, jepang, di, indonesia, pada, awal...
# 10  [kedatangan, jepang, di, indonesia, pada, awal...
# 11  [kedatangan, jepang, di, indonesia, pada, awal...
# 12            [dev, ##ano, adalah, seorang, pembunuh]
# 13               [dev, ##ano, tidak, memiliki, istri]
# 14           [ketiga, istri, dev, ##ano, bunuh, diri]
# 15  [ras, kulit, putih, telah, meninggalkan, indon...
# 16              [ras, kulit, putih, meninggal, dunia]
# 17  [tahun, 1942, adalah, hari, em, ##erdekaan, in...
# 18           [tentara, jepang, mendapatkan, serangan]
# 19                [gua, jepang, terletak, di, jepang]
# 20  [tentara, jepang, telah, menj, ##ajah, indonesia]
# 21  [rakyat, indonesia, menyukai, kedatangan, jepang]
# 22            [jepang, ke, indonesia, untuk, liburan]
# 23    [rakyat, indonesia, memiliki, hati, yang, baik]
# 24  [kedatangan, jepang, di, indonesia, pada, awal...
#
#                                           vector_repr  \
# 0   [1224, 633, 5780, 13126, 3335, 30468, 41, 2243...
# 1   [1224, 633, 5780, 13126, 3335, 30468, 41, 2243...
# 2   [1224, 633, 5780, 13126, 3335, 30468, 41, 2243...
# 3   [19298, 30468, 154, 633, 1668, 321, 722, 232, ...
# 4   [19298, 30468, 154, 633, 1668, 321, 722, 232, ...
# 5   [19298, 30468, 154, 633, 1668, 321, 722, 232, ...
# 6   [126, 890, 18540, 1794, 30468, 4599, 1794, 781...
# 7   [126, 890, 18540, 1794, 30468, 4599, 1794, 781...
# 8   [126, 890, 18540, 1794, 30468, 4599, 1794, 781...
# 9   [6570, 1794, 26, 300, 126, 3517, 11562, 79, 30...
# 10  [6570, 1794, 26, 300, 126, 3517, 11562, 79, 30...
# 11  [6570, 1794, 26, 300, 126, 3517, 11562, 79, 30...
# 12                     [5780, 13126, 154, 596, 11767]
# 13                      [5780, 13126, 119, 343, 2387]
# 14               [2243, 2387, 5780, 13126, 7576, 745]
# 15                 [2096, 1215, 1687, 351, 3134, 300]
# 16                      [2096, 1215, 1687, 1851, 594]
# 17             [262, 19298, 154, 406, 822, 5194, 300]
# 18                            [5085, 1794, 778, 3685]
# 19                       [4599, 1794, 2774, 26, 1794]
# 20                  [5085, 1794, 351, 171, 5688, 300]
# 21                      [1829, 300, 4847, 6570, 1794]
# 22                          [1794, 43, 300, 90, 3605]
# 23                    [1829, 300, 343, 1268, 34, 342]
# 24  [6570, 1794, 26, 300, 126, 3517, 11562, 79, 30...
#
#                                      embedding_result
# 0   [[[-0.4423386, 2.2751102, -0.007526504, 0.5282...
# 1   [[[-0.4423386, 2.2751102, -0.007526504, 0.5282...
# 2   [[[-0.4423386, 2.2751102, -0.007526504, 0.5282...
# 3   [[[-0.58352745, 2.300963, 0.013439208, 0.52970...
# 4   [[[-0.58352745, 2.300963, 0.013439208, 0.52970...
# 5   [[[-0.58352745, 2.300963, 0.013439208, 0.52970...
# 6   [[[-0.8451569, 2.219568, 0.20599273, 0.7148295...
# 7   [[[-0.8451569, 2.219568, 0.20599273, 0.7148295...
# 8   [[[-0.8451569, 2.219568, 0.20599273, 0.7148295...
# 9   [[[-0.6347034, 2.2512827, 0.24412957, 0.653939...
# 10  [[[-0.6347034, 2.2512827, 0.24412957, 0.653939...
# 11  [[[-0.6347034, 2.2512827, 0.24412957, 0.653939...
# 12  [[[-0.71225274, 2.376323, 0.21094957, 0.639126...
# 13  [[[-0.61061925, 2.347151, 0.27059254, 0.635419...
# 14  [[[-0.68112564, 2.3815398, 0.14597973, 0.61654...
# 15  [[[-0.5947068, 2.328565, 0.07702935, 0.6090675...
# 16  [[[-0.5576752, 2.2631001, 0.038909398, 0.60525...
# 17  [[[-0.76433074, 2.2156672, 0.24296996, 0.65547...
# 18  [[[-0.62139064, 2.3203435, 0.26210442, 0.61100...
# 19  [[[-0.6907055, 2.2065647, 0.15682265, 0.709324...
# 20  [[[-0.6993387, 2.3076394, 0.12622368, 0.617993...
# 21  [[[-0.64821416, 2.2370641, 0.25827056, 0.61129...
# 22  [[[-0.7528688, 2.3775034, 0.30986634, 0.695072...
# 23  [[[-0.69399625, 2.305635, 0.23957075, 0.667337...
# 24  [[[-0.6382439, 2.3010693, 0.30723557, 0.529480...

# %%
df_embed.to_csv('io_steps.csv')
df_embed.to_excel('io_steps.xlsx')

# %%
from tensorflow.keras.layers import Bidirectional, GRU, GlobalAveragePooling1D, GlobalMaxPooling1D
from tensorflow.keras.layers import LSTM, GRU, Add, Reshape

# %%
x = Bidirectional(LSTM(128, return_sequences=True,recurrent_dropout=0.2))(x)

# %%
for i, token_str in enumerate(tokenized_texts[0]):
  print (i, token_str)
# Out:
# 0 [CLS]
# 1 kedatangan
# 2 jepang
# 3 di
# 4 indonesia
# 5 pada
# 6 awalnya
# 7 disambut
# 8 dengan
# 9 senang
# 10 hati
# 11 oleh
# 12 rakyat
# 13 di
# 14 negara
# 15 ini
# 16 [SEP]

# %%
embeddings[0]
# Out:
# tensor([[-0.6382,  2.3011,  0.3072,  ..., -0.1035,  0.2020, -0.4965],
#         [-0.3931,  2.2726,  1.0264,  ...,  0.1639,  0.3706, -0.3244],
#         [-0.6397,  2.6094,  1.4012,  ...,  0.5967,  0.7286, -0.4166],
#         ...,
#         [ 0.6836,  1.1404, -0.3435,  ...,  1.4095, -0.3585,  0.7584],
#         [ 0.7307,  1.6367, -0.5175,  ...,  1.6511,  0.1349,  1.0184],
#         [ 0.7536,  1.6028, -0.1418,  ...,  1.5575,  0.5187,  1.1343]])

# %%
from scipy.spatial.distance import cosine

kings = cosine(embeddings[0][2], embeddings[0][4])
king_table = cosine(embeddings[0][4], embeddings[0][14])
king_archtur = cosine(embeddings[0][12], embeddings[0][4])

print('Jarak kata jepang dan indonesia:  %.2f' % kings)
print('Jarak kata indonesia dan negara:  %.2f' % king_table)
print('Jarak kata rakyat dan indonesia:  %.2f' % king_archtur)
# Out:
# Jarak kata jepang dan indonesia:  0.71
# Jarak kata indonesia dan negara:  0.68
# Jarak kata rakyat dan indonesia:  0.65
